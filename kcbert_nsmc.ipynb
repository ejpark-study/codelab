# %% [markdown]
# <a href="https://colab.research.google.com/github/ejpark78/codelab/blob/master/kcbert_nsmc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf kcBERT-nsmc
# !git clone https://github.com/beomi/kcBERT-nsmc
# !cd kcBERT-nsmc
# Out:
# Cloning into 'kcBERT-nsmc'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 180 (delta 103), reused 121 (delta 55), pack-reused 0
# Receiving objects: 100% (180/180), 8.10 MiB | 24.12 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
# !mv kcBERT-nsmc/* .
# Out:
# mv: cannot move 'kcBERT-nsmc/data' to './data': Directory not empty

# %%
# !pip install -q transformers

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("beomi/kcbert-base")
model = AutoModel.from_pretrained("beomi/kcbert-base")

# %%
import pandas as pd

# %%
# !python3 main.py \
    --model_name_or_path beomi/kcbert-base \
    --do_train --do_eval \
    --train_batch_size 64 \
    --eval_batch_size 128 \
    --learning_rate 1e-4 \
    --logging_steps 500 \
    --warmup_steps 1000 \
    --max_seq_len 146
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:   8% 177/2344 [02:22<29:07,  1.24it/s]
# Iteration:   8% 178/2344 [02:23<29:05,  1.24it/s]
# Iteration:   8% 179/2344 [02:24<29:03,  1.24it/s]
# Iteration:   8% 180/2344 [02:24<29:01,  1.24it/s]
# Iteration:   8% 181/2344 [02:25<28:57,  1.24it/s]
# Iteration:   8% 182/2344 [02:26<28:59,  1.24it/s]
# Iteration:   8% 183/2344 [02:27<28:57,  1.24it/s]
# Iteration:   8% 184/2344 [02:28<28:58,  1.24it/s]
# Iteration:   8% 185/2344 [02:28<28:55,  1.24it/s]
# Iteration:   8% 186/2344 [02:29<29:00,  1.24it/s]
# Iteration:   8% 187/2344 [02:30<28:58,  1.24it/s]
# Iteration:   8% 188/2344 [02:31<28:55,  1.24it/s]
# Iteration:   8% 189/2344 [02:32<29:01,  1.24it/s]
# Iteration:   8% 190/2344 [02:33<28:58,  1.24it/s]
# Iteration:   8% 191/2344 [02:33<28:58,  1.24it/s]
# Iteration:   8% 192/2344 [02:34<28:58,  1.24it/s]
# Iteration:   8% 193/2344 [02:35<28:52,  1.24it/s]
# Iteration:   8% 194/2344 [02:36<28:50,  1.24it/s]
# ...
