# %% [markdown]
# <a href="https://colab.research.google.com/github/ejpark78/codelab/blob/master/bert/huggingface_konlpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 튜토리얼 코드 clone

# %%
# !rm -rf sample_data
# !git init
# !git pull https://github.com/lovit/huggingface_konlpy.git
# !pip install -r requirements.txt
# !pip freeze | grep transformers

# mecab-ko 설치
# !curl -s https://raw.githubusercontent.com/SOMJANG/Mecab-ko-for-Google-Colab/master/install_mecab-ko_on_colab190912.sh | bash

# %% [markdown]
# # 결과 저장용 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 튜토리얼 코스 실행

# %%
# !PYTHONPATH=. python examples/run_konlpy_bert.py \
    --output_dir='/content/drive/My Drive/output' \
    --overwrite_output_dir \
    --model_type=bert \
    --config_name=examples/bert_config.json \
    --mlm \
    --vocab_file=tutorials/tokenizers/BertStyleMecab/notag-vocab.txt \
    --do_train \
    --train_data_file=data/2020-07-29_covid_news_sents.txt \
    --konlpy_name=mecab \
    --learning_rate=1e-4 \
    --num_train_epochs=3 \
    --save_total_limit=2 \
    --save_steps=2000 \
    --block_size=512 \
    --seed=42
# Out:
# 2020-09-25 22:08:30.859502: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# 09/25/2020 22:08:33 - INFO - transformers.training_args -   PyTorch: setting up devices
# 09/25/2020 22:08:33 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# ...
